# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from obspy import read
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Config
input_length = 3001
latent_dim = 128
batch_size = 64
epochs = 30

# Path split
splits_root = r"E:\Skripsi\DEC\dataset\ae-supervised-dataset\splits"
train_manifest = os.path.join(splits_root, "train.csv")
test_manifest  = os.path.join(splits_root, "test.csv")

# %%
def load_waveform(path):
    st = read(path)
    tr = st[0].data.astype(np.float32)
    return tr

def load_dataset(manifest_csv):
    df = pd.read_csv(manifest_csv)
    X = [load_waveform(p) for p in df["path"]]
    X = np.array(X)
    X = np.expand_dims(X, -1)   # shape (N, 3001, 1)
    return X, df["label"].values

# %%
X_train, y_train = load_dataset(train_manifest)
X_test, y_test   = load_dataset(test_manifest)

print("Train shape:", X_train.shape)
print("Test shape :", X_test.shape)
# Out:
# Train shape: (3861, 3001, 1)
# Test shape : (966, 3001, 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def build_autoencoder(input_length, latent_dim):
    inp = keras.Input(shape=(input_length,1))

    # === Encoder ===
    x = layers.Conv1D(16, 7, padding="same", activation="relu")(inp)
    x = layers.BatchNormalization()(x)   # Tambahkan BN
    x = layers.MaxPooling1D(2)(x)        # ~1500

    x = layers.Conv1D(32, 7, padding="same", activation="relu",
                      kernel_regularizer=keras.regularizers.l2(1e-4))(x)  # L2 lebih besar
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)        # ~750
    x = layers.Dropout(0.2)(x)           # Dropout lebih besar

    x = layers.Conv1D(64, 7, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)        # ~375

    x = layers.Flatten()(x)
    latent = layers.Dense(latent_dim, name="latent")(x)

    # === Decoder ===
    x = layers.Dense((input_length//8)*64)(latent)
    x = layers.Reshape((input_length//8, 64))(x)

    x = layers.Conv1DTranspose(32, 7, strides=2, padding="same", activation="relu")(x) # ~750
    x = layers.Conv1DTranspose(16, 7, strides=2, padding="same", activation="relu")(x) # ~1500
    x = layers.Conv1DTranspose(1, 7, strides=2, padding="same")(x)                     # ~3000

    x = layers.ZeroPadding1D(padding=(0,1))(x)   # dari 3000 → 3001

    model = keras.Model(inp, x, name="CAE")
    encoder = keras.Model(inp, latent, name="Encoder")
    return model, encoder

# %%
model.summary()

encoder.summary()
# Out:
# Model: "CAE"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 3001, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 3001, 16)       │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3001, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 1500, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 1500, 32)       │         3,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1500, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 750, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 750, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 750, 64)        │        14,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 750, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 375, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 24000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ latent (Dense)                  │ (None, 128)            │     3,072,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24000)          │     3,096,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 375, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_9              │ (None, 750, 32)        │        14,368 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_10             │ (None, 1500, 16)       │         3,600 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_11             │ (None, 3000, 1)        │           113 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding1d_3                │ (None, 3001, 1)        │             0 │
# │ (ZeroPadding1D)                 │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,613,957 (71.01 MB)
#  Trainable params: 6,204,577 (23.67 MB)
#  Non-trainable params: 224 (896.00 B)
#  Optimizer params: 12,409,156 (47.34 MB)
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 3001, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 3001, 16)       │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3001, 16)       │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 1500, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 1500, 32)       │         3,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1500, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 750, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 750, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 750, 64)        │        14,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 750, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_12 (MaxPooling1D) │ (None, 375, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 24000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ latent (Dense)                  │ (None, 128)            │     3,072,128 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,090,720 (11.79 MB)
#  Trainable params: 3,090,496 (11.79 MB)
#  Non-trainable params: 224 (896.00 B)

# %%
def spectral_loss(y_true, y_pred):
    # Hapus dim channel (N, 3001, 1) -> (N, 3001)
    y_true = tf.squeeze(y_true, -1)
    y_pred = tf.squeeze(y_pred, -1)
    
    # Short-Time Fourier Transform
    stft_true = tf.abs(tf.signal.stft(y_true, frame_length=256, frame_step=64))
    stft_pred = tf.abs(tf.signal.stft(y_pred, frame_length=256, frame_step=64))
    
    # MSE pada magnitude spektrum
    return tf.reduce_mean(tf.square(stft_true - stft_pred))

def combined_loss(y_true, y_pred):
    # Time-domain MSE
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    # Spectral MSE
    spec = spectral_loss(y_true, y_pred)
    # Gabungan
    return mse + 0.2 * spec   # β = 0.2 (bisa coba 0.1, 0.5)

# %%
model, encoder = build_autoencoder(input_length, latent_dim)
latent_dim = encoder.output_shape[1]
print(f"Encoder loaded. Latent dim = {latent_dim}")
# Out:
# Encoder loaded. Latent dim = 128

# %%
model.compile(optimizer=keras.optimizers.Adam(1e-3), loss=combined_loss)

callbacks = [
  tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
  tf.keras.callbacks.ModelCheckpoint("best_ae.h5", monitor="val_loss", save_best_only=True),
  tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, verbose=1)
]

history = model.fit(
    X_train, X_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=0.1
)
# Out:
# Epoch 1/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - loss: 8.4992 - val_loss: 19.3498
# Epoch 2/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - loss: 6.7322 - val_loss: 18.6181
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - loss: 6.3669 - val_loss: 17.9814
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - loss: 6.1175 - val_loss: 16.5393
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - loss: 5.8702 - val_loss: 13.2044
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - loss: 5.6984 - val_loss: 10.7512
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - loss: 5.5200 - val_loss: 9.1575
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - loss: 5.3999 - val_loss: 8.2170
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - loss: 5.2314 - val_loss: 7.0608
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - loss: 5.0723 - val_loss: 6.6122
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - loss: 4.9623 - val_loss: 6.6474
# Epoch 12/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - loss: 4.8505 - val_loss: 6.1091
# Epoch 13/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - loss: 4.7256 - val_loss: 6.3481
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - loss: 4.5751 - val_loss: 5.9637
# Epoch 15/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 245ms/step - loss: 4.4868 - val_loss: 5.8169
# Epoch 16/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 239ms/step - loss: 4.3999 - val_loss: 6.0145
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 226ms/step - loss: 4.2714 - val_loss: 5.8353
# Epoch 18/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - loss: 4.1888 - val_loss: 5.7230
# Epoch 19/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 225ms/step - loss: 4.0836 - val_loss: 5.7935
# Epoch 20/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 227ms/step - loss: 3.9841 - val_loss: 5.7094
# Epoch 21/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 243ms/step - loss: 3.8984 - val_loss: 5.7248
# Epoch 22/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 242ms/step - loss: 3.7967 - val_loss: 5.7611
# Epoch 23/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 236ms/step - loss: 3.7000 - val_loss: 5.6842
# Epoch 24/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 243ms/step - loss: 3.6202 - val_loss: 5.8134
# Epoch 25/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - loss: 3.5387 - val_loss: 5.8665
# Epoch 26/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━
100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 262ms/step - loss: 1.7081 - val_loss: 6.4852
# Epoch 71/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 291ms/step - loss: 1.6840 - val_loss: 6.4855
# Epoch 72/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 263ms/step - loss: 1.6736 - val_loss: 6.5348
# Epoch 73/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 262ms/step - loss: 1.6459 - val_loss: 6.5112
# Epoch 74/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 249ms/step - loss: 1.6177 - val_loss: 6.4753
# Epoch 75/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 248ms/step - loss: 1.6109 - val_loss: 6.4719
# Epoch 76/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 261ms/step - loss: 1.5932 - val_loss: 6.5480
# Epoch 77/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 248ms/step - loss: 1.5751 - val_loss: 6.5607
# Epoch 78/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 246ms/step - loss: 1.5551 - val_loss: 6.5272
# Epoch 79/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - loss: 1.5447 - val_loss: 6.5673
# Epoch 80/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - loss: 1.5374 - val_loss: 6.6191
# Epoch 81/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - loss: 1.4992 - val_loss: 6.5853
# Epoch 82/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - loss: 1.4982 - val_loss: 6.5575
# Epoch 83/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - loss: 1.4683 - val_loss: 6.6052
# Epoch 84/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 229ms/step - loss: 1.4393 - val_loss: 6.5777
# Epoch 85/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 266ms/step - loss: 1.4213 - val_loss: 6.6399
# Epoch 86/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - loss: 1.4109 - val_loss: 6.5545
# Epoch 87/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 14s 262ms/step - loss: 1.4001 - val_loss: 6.5541
# Epoch 88/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 266ms/step - loss: 1.3916 - val_loss: 6.5997
# Epoch 89/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 227ms/step - loss: 1.3868 - val_loss: 6.6723
# Epoch 90/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 232ms/step - loss: 1.3726 - val_loss: 6.5899
# Epoch 91/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - loss: 1.3542 - val_loss: 6.6575
# Epoch 92/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - loss: 1.3375 - val_loss: 6.5516
# Epoch 93/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - loss: 1.3268 - val_loss: 6.6426
# Epoch 94/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - loss: 1.3251 - val_loss: 6.7385
# Epoch 95/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - loss: 1.3086 - val_loss: 6.6411
# Epoch 96/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - loss: 1.2902 - val_loss: 6.6597
# Epoch 97/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - loss: 1.2769 - val_loss: 6.6617
# Epoch 98/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 227ms/step - loss: 1.2658 - val_loss: 6.7108
# Epoch 99/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 228ms/step - loss: 1.2595 - val_loss: 6.6538
# Epoch 100/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 232ms/step - loss: 1.2430 - val_loss: 6.7303

# %%
# Simpan hanya encoder
encoder = keras.Model(model.input, model.get_layer("latent").output)
encoder.save("encoder.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.title("Autoencoder Training Curve")
plt.show()

# %%
def plot_reconstruction_examples(model, X, y, n_classes=5, n_samples=1):
    labels = np.unique(y)
    for label in labels[:n_classes]:
        idxs = np.where(y == label)[0]
        for _ in range(n_samples):
            sample_idx = random.choice(idxs)
            x_in = X[sample_idx:sample_idx+1]
            x_out = model.predict(x_in)

            plt.figure(figsize=(12,4))
            plt.plot(x_in.flatten(), label="Input", color="blue")
            plt.plot(x_out.flatten(), label="Reconstruction", color="orange")
            plt.title(f"Class: {label} | Sample index: {sample_idx}")
            plt.xlabel("Time (samples)")
            plt.ylabel("Amplitude (normalized)")
            plt.legend()
            plt.show()

# === Cara pakai ===
plot_reconstruction_examples(model, X_test, y_test, n_classes=5, n_samples=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#      17             plt.show()
#      19 # === Cara pakai ===
# ---> 20 plot_reconstruction_examples(model, X_test, y_test, n_classes=5, n_samples=2)
#
# NameError: name 'model' is not defined
